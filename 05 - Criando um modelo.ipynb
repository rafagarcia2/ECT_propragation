# %% [markdown]
# ## Criando um modelo para os dados

# %% [markdown]
# O objetivo desse notebook é criar um modelo de dados para realizar predições com os dados já
# capturados.

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("data/outputs/estados_processados/estados_final.csv", sep=";")
data = data.iloc[:, 1:]

# %%
data.groupby('hash')['hash']

# %%
data.sort_values('qnt_discentes', ascending=False)
# Out:
#                                                    hash  qnt_discentes  \
# 4206        6ECT2101ECT2102ECT2103ECT2104ECT2105ECT2106            472
# 2016        6ECT2101ECT2102ECT2103ECT2104ECT2105ECT2106            465
# 864         6ECT2101ECT2102ECT2103ECT2104ECT2105ECT2106            396
# 3143        6ECT2101ECT2102ECT2103ECT2104ECT2105ECT2106            387
# 3427                                           1ECT2414            105
# 2351                                           1ECT2414             98
# 1171                                           1ECT2302             85
# 2247  7ECT2201ECT2202ECT2203ECT2204ECT2205ECT2206ECT...             84
# 2932               5ECT2102ECT2103ECT2104ECT2105ECT2106             75
# 2411                                    2ECT2206ECT2302             74
# 659                5ECT2102ECT2103ECT2104ECT2105ECT2106             68
# 4401  7ECT2201ECT2202ECT2203ECT2204ECT2205ECT2206ECT...             60
# ...
